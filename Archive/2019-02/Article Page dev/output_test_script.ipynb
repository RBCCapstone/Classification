# %%
import json
import pprint

# %%
art1tags = ["apple", "merger", "stocks"]
arttit = "Title Lorem ipsum dolor sit amet"
datetime = "2018-07-19  1:14:00 PM"
desc = "Etiam eget velit at erat tincidunt finibus. Praesent sodales mi sed ligula luctus, non aliquet leo bibendum. "
arttxt = "Lorem ipsum dolor sit amet, consectetur adipiscing elit. Etiam luctus suscipit dui, et elementum tortor molestie ullamcorper. Morbi ut risus enim. Morbi odio ex, interdum eu ipsum et, viverra ornare neque. In eget ultrices nibh. Donec tincidunt est eget quam consequat volutpat eu eu libero. Aliquam eget est et nibh interdum finibus. Fusce et nunc facilisis, gravida sapien et, iaculis dolor. Aenean semper convallis tortor, ac tempus metus aliquam eu. Aenean vitae ipsum nisi. Morbi lacus nisi, ornare ut dapibus ac, placerat hendrerit velit. Orci varius natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Duis et commodo tellus, vehicula aliquet odio. Pellentesque hendrerit vestibulum magna, quis suscipit ante blandit eu. Aliquam erat volutpat. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Pellentesque commodo vestibulum magna a dignissim. Curabitur a pellentesque massa. Fusce bibendum, lectus id aliquam fringilla, lacus velit efficitur magna, ut feugiat orci odio quis nibh. Morbi tristique, odio non porta ullamcorper, purus nibh dictum nisi, ac dictum enim elit sit amet nunc. Praesent quis maximus sapien. Sed et suscipit mauris. Nam ac finibus odio. In non magna at nibh finibus lobortis. Donec turpis turpis, aliquam a magna eu, iaculis tincidunt urna. Integer scelerisque, dui et eleifend consectetur, eros mi luctus nunc, nec consectetur lacus justo sed massa. Vivamus blandit velit in rutrum porta. Phasellus in neque vitae lacus congue accumsan. Vestibulum consequat orci vel lacus condimentum, vitae aliquam turpis porta. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Aliquam venenatis feugiat dui, vel accumsan justo auctor consectetur. Pellentesque id ornare ipsum. Donec commodo dignissim dui id tempus. Aliquam vulputate eget orci nec aliquam. Nullam eu magna ac lectus sollicitudin volutpat. Fusce sed lacus dignissim, bibendum odio et, condimentum augue. "

# %%
artarr = []
for i in range(30):
    tit = str(i) + arttit
    body = str(i) + arttxt
    art = {"title":tit, "body":body, "tags":art1tags, "datetime": datetime}
    artarr.append(art)

print(artarr[0]["tags"][0])
# Out:
# apple

# %%
topterms = [("amazon", 537), ("retail", 477), ("walmart", 350), ("sales", 310), ("target", 300), ("home depot", 245), ("walgreens", 235), ("jc penney", 156), ("lowes", 106), ("sears", 56)]

# %%
frontpage = {"topterms":topterms, "articles":artarr}
pprint.pprint(frontpage)
# Out:
# {'articles': [{'body': '0Lorem ipsum dolor sit amet, consectetur adipiscing '
#                        'elit. Etiam luctus suscipit dui, et elementum tortor '
#                        'molestie ullamcorper. Morbi ut risus enim. Morbi odio '
#                        'ex, interdum eu ipsum et, viverra ornare neque. In '
#                        'eget ultrices nibh. Donec tincidunt est eget quam '
#                        'consequat volutpat eu eu libero. Aliquam eget est et '
#                        'nibh interdum finibus. Fusce et nunc facilisis, '
#                        'gravida sapien et, iaculis dolor. Aenean semper '
#                        'convallis tortor, ac tempus metus aliquam eu. Aenean '
#                        'vitae ipsum nisi. Morbi lacus nisi, ornare ut dapibus '
#                        'ac, placerat hendrerit velit. Orci varius natoque '
#                        'penatibus et magnis dis parturient montes, nascetur '
# ...

# %%
with open("frontPage.json", "w") as write_file:
    json.dump(frontpage, write_file)

# %% [markdown]
# article page

# %%
source = "WSJ"
mainarticle = {"title":arttit, "body":arttxt, "tags":art1tags, "datetime": datetime, "source":source}

# %%
relarts = []
for i in range(3):
    tit = str(i) + arttit
    art = {"title":tit, "source":source, "tags":art1tags, "datetime": datetime}
    relarts.append(art)

print(relarts[0]["tags"][0])
# Out:
# apple

# %%
articlepage = {"main article": mainarticle, "related articles": relarts}

# %%
with open("articlePage.json", "w") as write_file:
    json.dump(articlepage, write_file)
